# %%
# %%!
# pip install --trusted-host pypi.org ipython-sql
# Out:
# ['Requirement already satisfied: ipython-sql in c:\\progra~1\\qgis3~1.10\\apps\\python37\\lib\\site-packages (0.3.9)',
#  'Requirement already satisfied: ipython>=1.0 in c:\\progra~1\\qgis3~1.10\\apps\\python37\\lib\\site-packages (from ipython-sql) (7.13.0)',
#  'Requirement already satisfied: prettytable in c:\\progra~1\\qgis3~1.10\\apps\\python37\\lib\\site-packages (from ipython-sql) (0.7.2)',
#  'Requirement already satisfied: sqlparse in c:\\progra~1\\qgis3~1.10\\apps\\python37\\lib\\site-packages (from ipython-sql) (0.3.1)',
#  'Requirement already satisfied: ipython-genutils>=0.1.0 in c:\\progra~1\\qgis3~1.10\\apps\\python37\\lib\\site-packages (from ipython-sql) (0.2.0)',
#  'Requirement already satisfied: six in c:\\progra~1\\qgis3~1.10\\apps\\python37\\lib\\site-packages (from ipython-sql) (1.12.0)',
#  'Requirement already satisfied: sqlalchemy>=0.6.7 in c:\\progra~1\\qgis3~1.10\\apps\\python37\\lib\\site-packages (from ipython-sql) (1.3.16)',
#  'Requirement already satisfied: jedi>=0.10 in c:\\progra~1\\qgis3~1.10\\apps\\python37\\lib\\site-packages (from ipython>=1.0->ipython-sql) (0.17.0)',
#  'Requirement already satisfied: decorator in c:\\progra~1\\qgis3~1.10\\apps\\python37\\lib\\site-packages (from ipython>=1.0->ipython-sql) (4.3.0)',
#  'Requirement already satisfied: prompt-toolkit!=3.0.0,!=3.0.1,<3.1.0,>=2.0.0 in c:\\progra~1\\qgis3~1.10\\apps\\python37\\lib\\site-packages (from ipython>=1.0->ipython-sql) (3.0.5)',
#  'Requirement already satisfied: traitlets>=4.2 in c:\\progra~1\\qgis3~1.10\\apps\\python37\\lib\\site-packages (from ipython>=1.0->ipython-sql) (4.3.2)',
#  'Requirement already satisfied: pickleshare in c:\\progra~1\\qgis3~1.10\\apps\\python37\\lib\\site-packages (from ipython>=1.0->ipython-sql) (0.7.5)',
#  'Requirement already satisfied: backcall in c:\\progra~1\\qgis3~1.10\\apps\\python37\\lib\\site-packages (from ipython>=1.0->ipython-sql) (0.1.0)',
#  'Requirement already satisfied: setuptools>=18.5 in c:\\progra~1\\qgis3~1.10\\apps\\python37\\lib\\site-packages (from ipython>=1.0->ipython-sql) (42.0.2)',
#  'Requirement already satisfied: pygments in c:\\progra~1\\qgis3~1.10\\apps\\python37\\lib\\site-packages (from ipython>=1.0->ipython-sql) (2.2.0)',
#  'Requirement already satisfied: colorama; sys_platform == "win32" in c:\\progra~1\\qgis3~1.10\\apps\\python37\\lib\\site-packages (from ipython>=1.0->ipython-sql) (0.4.3)',
#  'Requirement already satisfied: parso>=0.7.0 in c:\\progra~1\\qgis3~1.10\\apps\\python37\\lib\\site-packages (from jedi>=0.10->ipython>=1.0->ipython-sql) (0.7.0)',
#  'Requirement already satisfied: wcwidth in c:\\progra~1\\qgis3~1.10\\apps\\python37\\lib\\site-packages (from prompt-toolkit!=3.0.0,!=3.0.1,<3.1.0,>=2.0.0->ipython>=1.0->ipython-sql) (0.1.9)']

# %%
# %load_ext sql

# %%
import os
import psycopg2

hostname = 'localhost'
username = 'postgres'
password = '..'
database = 'MIEBIOM'

def doQuery( conn ) :
    cur = conn.cursor()

    cur.execute( "select * from covid" )

    for x in cur.fetchall() :
        print (x)

myConnection = psycopg2.connect( host=hostname, user=username, password=password, dbname=database )
doQuery( myConnection )
# Out:
# ---------------------------------------------------------------------------
# OperationalError                          Traceback (most recent call last)
# <ipython-input-6-9a130d896e05> in <module>
#      15         print (x)
#      16
# ---> 17 myConnection = psycopg2.connect( host=hostname, user=username, password=password, dbname=database )
#      18 doQuery( myConnection )
#
# C:\PROGRA~1\QGIS3~1.10\apps\Python37\lib\site-packages\psycopg2\__init__.py in connect(dsn, connection_factory, cursor_factory, **kwargs)
#     124
#     125     dsn = _ext.make_dsn(dsn, **kwargs)
# --> 126     conn = _connect(dsn, connection_factory=connection_factory, **kwasync)
#     127     if cursor_factory is not None:
#     128         conn.cursor_factory = cursor_factory
#
# OperationalError: FATAL:  password authentication failed for user "postgres"

# %%
import os

user = os.getenv('user')
password = os.getenv('pass')
connection_string = "postgresql://postgres:..@localhost/MIEBIOM".format(user=user, password=password)
# %sql $connection_string
# Out:
# (psycopg2.OperationalError) FATAL:  password authentication failed for user "postgres"
#
# (Background on this error at: http://sqlalche.me/e/e3q8)
# Connection info needed in SQLAlchemy format, example:
#                postgresql://username:password@hostname/dbname
#                or an existing connection: dict_keys(['postgresql://postgres:***@localhost/MIEBIOM'])

# %%
# %sql select concelho from "Portugal"
# Out:
#  * postgresql://postgres:***@localhost/MIEBIOM
# 3223 rows affected.
# [('FARO',),
#  ('VILA DO BISPO',),
#  ('VILA DO BISPO',),
#  ('ALBUFEIRA',),
#  ('ALBUFEIRA',),
#  ('ALBUFEIRA',),
#  ('LAGOS',),
#  ('ALBUFEIRA',),
#  ('ALBUFEIRA',),
#  ('ALBUFEIRA',),
#  ('OLHÃO',),
#  ('ALBUFEIRA',),
#  ('ALBUFEIRA',),
#  ('ALBUFEIRA',),
#  ('ALBUFEIRA',),
#  ('ALBUFEIRA',),
#  ('VILA DO BISPO',),
#  ('ALBUFEIRA',),
#  ('ALBUFEIRA',),
#  ('ALBUFEIRA',),
#  ('ALBUFEIRA',),
#  ('ALBUFEIRA',),
#  ('ALBUFEIRA',),
#  ('ALBUFEIRA',),
#  ('ALBUFEIRA',),
#  ('OURIQUE',),
#  ('ODEMIRA',),
#  ('ALBUFEIRA',),
#  ('LAGOS',),
#  ('VILA DO BISPO',),
#  ('VILA DO BISPO',),
#  ('VILA DO BISPO',),
#  ('VILA DO BISPO',),
#  ('VILA DO BISPO',),
#  ('VILA DO BISPO',),
#  ('VILA DO BISPO',),
#  ('VILA DO BISPO',),
#  ('OURIQUE',),
#  ('VILA DO BISPO',),
#  ('VILA DO BISPO',),
#  ('VILA DO BISPO',),
#  ('VILA DO BISPO',),
#  ('VILA DO BISPO',),
#  ('VILA DO BISPO',),
#  ('VILA DO BISPO',),
#  ('VILA DO BISPO',),
#  ('VILA DO BISPO',),
#  ('VILA DO BISPO',),
#  ('VILA DO BISPO',),
#  ('VILA DO BISPO',),
#  ('OLHÃO',),
#  ('VILA DO BISPO',),
#  ('VILA DO BISPO',),
#  ('VILA DO BISPO',),
#  ('VILA DO BISPO',),
#  ('ODEMIRA',),
#  ('MÉRTOLA',),
#  ('MÉRTOLA',),
#  ('VILA DO BISPO',),
#  ('FARO',),
#  ('LAGOS',),
#  ('LAGOS',),
#  ('OLHÃO',),
#  ('LAGOS',),
#  ('ALBUFEIRA',),
#  ('ALBUFEIRA',),
#  ('ALBUFEIRA',),
#  ('ALBUFEIRA',),
#  ('LAGOS',),
#  ('CASTRO VERDE',),
#  ('ALBUFEIRA',),
#  ('LAGOS',),
#  ('LAGOS',),
#  ('ALBUFEIRA',),
#  ('ALBUFEIRA',),
#  ('LAGOS',),
#  ('ALBUFEIRA',),
#  ('ALBUFEIRA',),
#  ('LAGOS',),
#  ('LAGOS',),
#  ('CASTRO VERDE',),
#  ('ALBUFEIRA',),
#  ('LAGOS',),
#  ('ALBUFEIRA',),
#  ('ALBUFEIRA',),
#  ('ALBUFEIRA',),
#  ('LAGOS',),
#  ('LAGOS',),
#  ('LAGOA',),
#  ('LAGOS',),
#  ('LAGOS',),
#  ('LAGOS',),
#  ('ODEMIRA',),
#  ('CASTRO VERDE',),
#  ('ODEMIRA',),
#  ('LAGOS',),
#  ('LAGOA',),
#  ('LAGOA',),
#  ('LAGOS',),
#  ('LAGOS',),
#  ('LAGOA',),
#  ('LAGOS',),
#  ('LAGOS',),
#  ('LAGOA',),
#  ('LAGOA',),
#  ('LAGOS',),
#  ('MÉRTOLA',),
#  ('CASCAIS',),
#  ('LAGOS',),
#  ('LAGOS',),
#  ('LAGOS',),
#  ('LAGOS',),
#  ('LAGOS',),
#  ('LAGOS',),
#  ('LAGOS',),
#  ('LAGOS',),
#  ('LAGOS',),
#  ('ALMODÔVAR',),
#  ('MÉRTOLA',),
#  ('ALMODÔVAR',),
#  ('ODEMIRA',),
#  ('ODEMIRA',),
#  ('MÉRTOLA',),
#  ('CASTRO VERDE',),
#  ('ODEMIRA',),
#  ('MÉRTOLA',),
#  ('ODEMIRA',),
#  ('ODEMIRA',),
#  ('SINES',),
#  ('MÉRTOLA',),
#  ('OURIQUE',),
#  ('LISBOA',),
#  ('CASCAIS',),
#  ('CASCAIS',),
#  ('CASCAIS',),
#  ('CASCAIS',),
#  ('CASCAIS',),
#  ('CASCAIS',),
#  ('CASCAIS',),
#  ('LISBOA',),
#  ('CASCAIS',),
#  ('CASCAIS',),
#  ('CASCAIS',),
#  ('CASCAIS',),
#  ('CASCAIS',),
#  ('CASCAIS',),
#  ('AMADORA',),
#  ('LISBOA',),
#  ('CRATO',),
#  ('BOMBARRAL',),
#  ('PORTALEGRE',),
#  ('BOMBARRAL',),
#  ('GOLEGÃ',),
#  ('ÓBIDOS',),
#  ('PONTE DE SOR',),
#  ('SANTARÉM',),
#  ('ÓBIDOS',),
#  ('LISBOA',),
#  ('ÉVORA',),
#  ('RIO MAIOR',),
#  ('PORTALEGRE',),
#  ('ÓBIDOS',),
#  ('PENICHE',),
#  ('PENICHE',),
#  ('PENICHE',),
#  ('CRATO',),
#  ('SINTRA',),
#  ('SANTARÉM',),
#  ('SANTARÉM',),
#  ('PONTE DE SOR',),
#  ('CHAMUSCA',),
#  ('PORTALEGRE',),
#  ('CRATO',),
#  ('PORTO DE MÓS',),
#  ('ALCOBAÇA',),
#  ('OURÉM',),
#  ('NISA',),
#  ('OURÉM',),
#  ('MAÇÃO',),
#  ('BATALHA',),
#  ('MAÇÃO',),
#  ('OURÉM',),
#  ('TOMAR',),
#  ('BATALHA',),
#  ('BATALHA',),
#  ('TOMAR',),
#  ('BATALHA',),
#  ('AMADORA',),
#  ('CASCAIS',),
#  ('VILA VIÇOSA',),
#  ('ALANDROAL',),
#  ('TOMAR',),
#  ('OURÉM',),
#  ('PROENÇA-A-NOVA',),
#  ('TOMAR',),
#  ('OURÉM',),
#  ('FERREIRA DO ZÊZERE',),
#  ('VILA VELHA DE RÓDÃO',),
#  ('LEIRIA',),
#  ('FERREIRA DO ZÊZERE',),
#  ('LISBOA',),
#  ('SANTARÉM',),
#  ('ALTER DO CHÃO',),
#  ('BOMBARRAL',),
#  ('CALDAS DA RAINHA',),
#  ('LEIRIA',),
#  ('MARINHA GRANDE',),
#  ('VILA DE REI',),
#  ('SABUGAL',),
#  ('PENACOVA',),
#  ('OLIVEIRA DO HOSPITAL',),
#  ('SEIA',),
#  ('COVILHÃ',),
#  ('SABUGAL',),
#  ('SABUGAL',),
#  ('MEALHADA',),
#  ('FIGUEIRA DA FOZ',),
#  ('PENAMACOR',),
#  ('OLIVEIRA DO HOSPITAL',),
#  ('SABUGAL',),
#  ('BELMONTE',),
#  ('COVILHÃ',),
#  ('CANTANHEDE',),
#  ('SABUGAL',),
#  ('SEIA',),
#  ('PENACOVA',),
#  ('TÁBUA',),
#  ('PENACOVA',),
#  ('AVEIRO',),
#  ('ALMEIDA',),
#  ('TONDELA',),
#  ('MONÇÃO',),
#  ('LAGOA',),
#  ('ALJEZUR',),
#  ('VILA REAL DE SANTO ANTÓNIO',),
#  ('SABUGAL',),
#  ('ARCOS DE VALDEVEZ',),
#  ('LAGOA',),
#  ('ALJEZUR',),
#  ('OLIVEIRA DO HOSPITAL',),
#  ('ALJEZUR',),
#  ('TÁBUA',),
#  ('COIMBRA',),
#  ('OLIVEIRA DO HOSPITAL',),
#  ('CELORICO DA BEIRA',),
#  ('ALJEZUR',),
#  ('OLIVEIRA DO HOSPITAL',),
#  ('MANGUALDE',),
#  ('MANGUALDE',),
#  ('ALJEZUR',),
#  ('MOURA',),
#  ('GUARDA',),
#  ('VISEU',),
#  ('ÍLHAVO',),
#  ('GUARDA',),
#  ('CELORICO DA BEIRA',),
#  ('GUARDA',),
#  ('ALMEIDA',),
#  ('LAGOA',),
#  ('BEJA',),
#  ('GUARDA',),
#  ('GOUVEIA',),
#  ('GUARDA',),
#  ('GUARDA',),
#  ('TONDELA',),
#  ('ÁGUEDA',),
#  ('ÁGUEDA',),
#  ('TONDELA',),
#  ('TONDELA',),
#  ('MANGUALDE',),
#  ('ÁGUEDA',),
#  ('TONDELA',),
#  ('CELORICO DA BEIRA',),
#  ('ARCOS DE VALDEVEZ',),
#  ('LAGOA',),
#  ('LOULÉ',),
#  ('ALJEZUR',),
#  ('FERREIRA DO ALENTEJO',),
#  ('SERPA',),
#  ('VALENÇA',),
#  ('MONÇÃO',),
#  ('VINHAIS',),
#  ('ARCOS DE VALDEVEZ',),
#  ('BRAGANÇA',),
#  ('ALJEZUR',),
#  ('VALENÇA',),
#  ('MONÇÃO',),
#  ('MONÇÃO',),
#  ('MONÇÃO',),
#  ('VALENÇA',),
#  ('VALENÇA',),
#  ('ALJEZUR',),
#  ('MONÇÃO',),
#  ('MONÇÃO',),
#  ('MONÇÃO',),
#  ('FERREIRA DO ALENTEJO',),
#  ('ALCÁCER DO SAL',),
#  ('VALENÇA',),
#  ('VALENÇA',),
#  ('VIDIGUEIRA',),
#  ('GRÂNDOLA',),
#  ('MONÇÃO',),
#  ('MONÇÃO',),
#  ('MONÇÃO',),
#  ('MONÇÃO',),
#  ('MONÇÃO',),
#  ('MELGAÇO',),
#  ('ALJEZUR',),
#  ('VALENÇA',),
#  ('LAGOS',),
#  ('LAGOS',),
#  ('VILA DO BISPO',),
#  ('VILA DO BISPO',),
#  ('VILA DO BISPO',),
#  ('VILA DO BISPO',),
#  ('LAGOA',),
#  ('VILA DO BISPO',),
#  ('ALJEZUR',),
#  ('LOULÉ',),
#  ('TAVIRA',),
#  ('LOULÉ',),
#  ('ALBUFEIRA',),
#  ('LAGOS',),
#  ('OLHÃO',),
#  ('SILVES',),
#  ('LAGOA',),
#  ('FARO',),
#  ('VILA DO BISPO',),
#  ('ALBUFEIRA',),
#  ('FARO',),
#  ('LAGOA',),
#  ('ALBUFEIRA',),
#  ('LAGOA',),
#  ('LAGOS',),
#  ('VILA DO BISPO',),
#  ('ALJEZUR',),
#  ('VILA DO BISPO',),
#  ('PORTIMÃO',),
#  ('ALJEZUR',),
#  ('ALJEZUR',),
#  ('ALJEZUR',),
#  ('ALJEZUR',),
#  ('ALJEZUR',),
#  ('ALJEZUR',),
#  ('TAVIRA',),
#  ('ALJEZUR',),
#  ('ALJEZUR',),
#  ('LAGOA',),
#  ('ALJEZUR',),
#  ('ALJEZUR',),
#  ('ALJEZUR',),
#  ('ALJEZUR',),
#  ('ALJEZUR',),
#  ('ALJEZUR',),
#  ('LOULÉ',),
#  ('LOULÉ',),
#  ('ALJEZUR',),
#  ('ALJEZUR',),
#  ('ALJEZUR',),
#  ('ALJEZUR',),
#  ('ALJEZUR',),
#  ('ALJEZUR',),
#  ('ALJEZUR',),
#  ('PALMELA',),
#  ('ALJEZUR',),
#  ('ALJEZUR',),
#  ('ALJEZUR',),
#  ('ALJEZUR',),
#  ('LAGOS',),
#  ('SILVES',),
#  ('SILVES',),
#  ('CASTRO MARIM',),
#  ('VILA REAL DE SANTO ANTÓNIO',),
#  ('ALBUFEIRA',),
#  ('ALJEZUR',),
#  ('ALJEZUR',),
#  ('LAGOS',),
#  ('PORTIMÃO',),
#  ('ALJEZUR',),
#  ('VILA REAL DE SANTO ANTÓNIO',),
#  ('TAVIRA',),
#  ('SÃO BRÁS DE ALPORTEL',),
#  ('TAVIRA',),
#  ('ALJEZUR',),
#  ('CASTRO MARIM',),
#  ('ALJEZUR',),
#  ('ALJEZUR',),
#  ('PORTIMÃO',),
#  ('LOULÉ',),
#  ('ALJEZUR',),
#  ('ALJEZUR',),
#  ('TAVIRA',),
#  ('ALJEZUR',),
#  ('ÉVORA',),
#  ('ALJEZUR',),
#  ('ALJEZUR',),
#  ('ALJEZUR',),
#  ('ALJEZUR',),
#  ('ALJEZUR',),
#  ('ALJEZUR',),
#  ('ALJEZUR',),
#  ('ALJEZUR',),
#  ('ALJEZUR',),
#  ('ALJEZUR',),
#  ('ALJEZUR',),
#  ('ALJEZUR',),
#  ('ALJEZUR',),
#  ('ALJEZUR',),
#  ('ALJEZUR',),
#  ('ALJEZUR',),
#  ('ALJEZUR',),
#  ('ALJEZUR',),
#  ('ALJEZUR',),
#  ('ALANDROAL',),
#  ('ALJEZUR',),
#  ('ALJEZUR',),
#  ('ALJEZUR',),
#  ('ALJEZUR',),
#  ('ALJEZUR',),
#  ('SILVES',),
#  ('ALJEZUR',),
#  ('ALJEZUR',),
#  ('ALJEZUR',),
#  ('ALJEZUR',),
#  ('ALJEZUR',),
#  ('ALJEZUR',),
#  ('ALJEZUR',),
#  ('ALJEZUR',),
#  ('ALJEZUR',),
#  ('ALJEZUR',),
#  ('ALJEZUR',),
#  ('ALJEZUR',),
#  ('ALJEZUR',),
#  ('ALJEZUR',),
#  ('MÊDA',),
#  ('ALJEZUR',),
#  ('ALJEZUR',),
#  ('ALJEZUR',),
#  ('ALJEZUR',),
#  ('ALJEZUR',),
#  ('ALJEZUR',),
#  ('ALJEZUR',),
#  ('ALJEZUR',),
#  ('ALJEZUR',),
#  ('ALJEZUR',),
#  ('ALJEZUR',),
#  ('ALJEZUR',),
#  ('ALJEZUR',),
#  ('CASTRO MARIM',),
#  ('LOULÉ',),
#  ('LOULÉ',),
#  ('ALJEZUR',),
#  ('ALJEZUR',),
#  ('ALJEZUR',),
#  ('ÉVORA',),
#  ('ALJEZUR',),
#  ('SILVES',),
#  ('ALJEZUR',),
#  ('ALJEZUR',),
#  ('ALJEZUR',),
#  ('MONCHIQUE',),
#  ('TAVIRA',),
#  ('ALJEZUR',),
#  ('ALJEZUR',),
#  ('ALJEZUR',),
#  ('ALJEZUR',),
#  ('CASTRO MARIM',),
#  ('MONCHIQUE',),
#  ('ALJEZUR',),
#  ('MONCHIQUE',),
#  ('ALJEZUR',),
#  ('ALJEZUR',),
#  ('ALJEZUR',),
#  ('ALJEZUR',),
#  ('ALJEZUR',),
#  ('LOULÉ',),
#  ('ALCOUTIM',),
#  ('ALJEZUR',),
#  ('ALJEZUR',),
#  ('ALJEZUR',),
#  ('ALJEZUR',),
#  ('ALJEZUR',),
#  ('ALJEZUR',),
#  ('ALJEZUR',),
#  ('ALJEZUR',),
#  ('ALMODÔVAR',),
#  ('ALJEZUR',),
#  ('ALJEZUR',),
#  ('ALJEZUR',),
#  ('ALJEZUR',),
#  ('ALJEZUR',),
#  ('ALJEZUR',),
#  ('ALJEZUR',),
#  ('ALJEZUR',),
#  ('ALJEZUR',),
#  ('SILVES',),
#  ('ALJEZUR',),
#  ('ALCOUTIM',),
#  ('ALCOUTIM',),
#  ('ALMODÔVAR',),
#  ('ALCOUTIM',),
#  ('ODEMIRA',),
#  ('ALMODÔVAR',),
#  ('OURIQUE',),
#  ('ODEMIRA',),
#  ('ALMODÔVAR',),
#  ('ODEMIRA',),
#  ('ODEMIRA',),
#  ('SINES',),
#  ('SANTIAGO DO CACÉM',),
#  ('ALJUSTREL',),
#  ('BEJA',),
#  ('SINES',),
#  ('SINES',),
#  ('SINES',),
#  ('SINES',),
#  ('SINES',),
#  ('SINES',),
#  ('SINES',),
#  ('SINES',),
#  ('SINES',),
#  ('SINES',),
#  ('SINES',),
#  ('SINES',),
#  ('SANTIAGO DO CACÉM',),
#  ('SINES',),
#  ('SINES',),
#  ('ÉVORA',),
#  ('SINES',),
#  ('SINES',),
#  ('BEJA',),
#  ('SINES',),
#  ('SINES',),
#  ('ALJUSTREL',),
#  ('SINES',),
#  ('SINES',),
#  ('SINES',),
#  ('SINES',),
#  ('SESIMBRA',),
#  ('SESIMBRA',),
#  ('SESIMBRA',),
#  ('SINES',),
#  ('ALJUSTREL',),
#  ('SANTIAGO DO CACÉM',),
#  ('BEJA',),
#  ('ALJUSTREL',),
#  ('BEJA',),
#  ('SERPA',),
#  ('SERPA',),
#  ('SINES',),
#  ('BEJA',),
#  ('SERPA',),
#  ('BEJA',),
#  ('SANTIAGO DO CACÉM',),
#  ('SANTIAGO DO CACÉM',),
#  ('SESIMBRA',),
#  ('SESIMBRA',),
#  ('SESIMBRA',),
#  ('SESIMBRA',),
#  ('SESIMBRA',),
#  ('SESIMBRA',),
#  ('PORTEL',),
#  ('SESIMBRA',),
#  ('BEJA',),
#  ('BEJA',),
#  ('SESIMBRA',),
#  ('SESIMBRA',),
#  ('SESIMBRA',),
#  ('BEJA',),
#  ('SANTIAGO DO CACÉM',),
#  ('SERPA',),
#  ('MOURA',),
#  ('SESIMBRA',),
#  ('SESIMBRA',),
#  ('SESIMBRA',),
#  ('SESIMBRA',),
#  ('SESIMBRA',),
#  ('BEJA',),
#  ('BEJA',),
#  ('SANTIAGO DO CACÉM',),
#  ('SANTIAGO DO CACÉM',),
#  ('FERREIRA DO ALENTEJO',),
#  ('MOURÃO',),
#  ('CUBA',),
#  ('VIDIGUEIRA',),
#  ('GRÂNDOLA',),
#  ('CUBA',),
#  ('FERREIRA DO ALENTEJO',),
#  ('BARRANCOS',),
#  ('VIDIGUEIRA',),
#  ('MOURA',),
#  ('VIDIGUEIRA',),
#  ('PORTEL',),
#  ('CUBA',),
#  ('CUBA',),
#  ('MOURA',),
#  ('GRÂNDOLA',),
#  ('SESIMBRA',),
#  ('SEIXAL',),
#  ('ÉVORA',),
#  ('CUBA',),
#  ('PORTEL',),
#  ('ALVITO',),
#  ('ALVITO',),
#  ('MOURÃO',),
#  ('MOURA',),
#  ('ALCÁCER DO SAL',),
#  ('PORTEL',),
#  ('MOURÃO',),
#  ('PORTEL',),
#  ('VIANA DO ALENTEJO',),
#  ('PORTEL',),
#  ('REGUENGOS DE MONSARAZ',),
#  ('VIANA DO ALENTEJO',),
#  ('SESIMBRA',),
#  ('SESIMBRA',),
#  ('SESIMBRA',),
#  ('SESIMBRA',),
#  ('SESIMBRA',),
#  ('SETÚBAL',),
#  ('SETÚBAL',),
#  ('VIANA DO ALENTEJO',),
#  ('GRÂNDOLA',),
#  ('REGUENGOS DE MONSARAZ',),
#  ('REGUENGOS DE MONSARAZ',),
#  ('REGUENGOS DE MONSARAZ',),
#  ('ÉVORA',),
#  ('SETÚBAL',),
#  ('ÉVORA',),
#  ('ALCÁCER DO SAL',),
#  ('REDONDO',),
#  ('ALCÁCER DO SAL',),
#  ('SETÚBAL',),
#  ('ÉVORA',),
#  ('SETÚBAL',),
#  ('SESIMBRA',),
#  ('SETÚBAL',),
#  ('SESIMBRA',),
#  ('MONTEMOR-O-NOVO',),
#  ('ÉVORA',),
#  ('SEIXAL',),
#  ('ALANDROAL',),
#  ('SETÚBAL',),
#  ('MONTEMOR-O-NOVO',),
#  ('BARREIRO',),
#  ('PALMELA',),
#  ('BARREIRO',),
#  ('VENDAS NOVAS',),
#  ('ALANDROAL',),
#  ('CASCAIS',),
#  ('ÉVORA',),
#  ('MONTEMOR-O-NOVO',),
#  ('SEIXAL',),
#  ('SEIXAL',),
#  ('BARREIRO',),
#  ('ALMADA',),
#  ('ALMADA',),
#  ('ALMADA',),
#  ('MOITA',),
#  ('PALMELA',),
#  ('ALMADA',),
#  ('MOITA',),
#  ('MOITA',),
#  ('CASCAIS',),
#  ('CASCAIS',),
#  ('CASCAIS',),
#  ('MONTEMOR-O-NOVO',),
#  ('ALMADA',),
#  ('BARREIRO',),
#  ('MOITA',),
#  ('ÉVORA',),
#  ('ÉVORA',),
#  ('MONTIJO',),
#  ('CASCAIS',),
#  ('MONTIJO',),
#  ('BORBA',),
#  ('ARRAIOLOS',),
#  ('VILA VIÇOSA',),
#  ('SINTRA',),
#  ('ESTREMOZ',),
#  ('LOURES',),
#  ('MONTEMOR-O-NOVO',),
#  ('LOURES',),
#  ('ELVAS',),
#  ('LISBOA',),
#  ('LISBOA',),
#  ('OEIRAS',),
#  ('MONTIJO',),
#  ('LISBOA',),
#  ('BENAVENTE',),
#  ('MAFRA',),
#  ('ESTREMOZ',),
#  ('CORUCHE',),
#  ('MAFRA',),
#  ('MAFRA',),
#  ('MAFRA',),
#  ('MONFORTE',),
#  ('MORA',),
#  ('LISBOA',),
#  ('OEIRAS',),
#  ('SOUSEL',),
#  ('VILA FRANCA DE XIRA',),
#  ('SOUSEL',),
#  ('MAFRA',),
#  ('MORA',),
#  ('ELVAS',),
#  ('MAFRA',),
#  ('ARRUDA DOS VINHOS',),
#  ('BENAVENTE',),
#  ('VILA FRANCA DE XIRA',),
#  ('MAFRA',),
#  ('SOBRAL DE MONTE AGRAÇO',),
#  ('LISBOA',),
#  ('LISBOA',),
#  ('MONTIJO',),
#  ('SOBRAL DE MONTE AGRAÇO',),
#  ('LISBOA',),
#  ('CASCAIS',),
#  ('CASCAIS',),
#  ('CASCAIS',),
#  ('ALENQUER',),
#  ('CAMPO MAIOR',),
#  ('TORRES VEDRAS',),
#  ('AVIS',),
#  ('ELVAS',),
#  ('CORUCHE',),
#  ('ALENQUER',),
#  ('MAFRA',),
#  ('TORRES VEDRAS',),
#  ('SALVATERRA DE MAGOS',),
#  ('SALVATERRA DE MAGOS',),
#  ('AZAMBUJA',),
#  ('ALENQUER',),
#  ('FRONTEIRA',),
#  ('LISBOA',),
#  ('AMADORA',),
#  ('CASCAIS',),
#  ('LISBOA',),
#  ('CASCAIS',),
#  ('CASCAIS',),
#  ('CASCAIS',),
#  ('CASCAIS',),
#  ('CASCAIS',),
#  ('CASCAIS',),
#  ('TORRES VEDRAS',),
#  ('TORRES VEDRAS',),
#  ('AVIS',),
#  ('CORUCHE',),
#  ('ALENQUER',),
#  ('SALVATERRA DE MAGOS',),
#  ('LISBOA',),
#  ('LISBOA',),
#  ('ALCOCHETE',),
#  ('ALCOCHETE',),
#  ('CORUCHE',),
#  ('LISBOA',),
#  ('PALMELA',),
#  ('OEIRAS',),
#  ('CASCAIS',),
#  ('TORRES VEDRAS',),
#  ('TORRES VEDRAS',),
#  ('CAMPO MAIOR',),
#  ('AVIS',),
#  ('ALENQUER',),
#  ('CAMPO MAIOR',),
#  ('MONFORTE',),
#  ('ALENQUER',),
#  ('AZAMBUJA',),
#  ('AVIS',),
#  ('AZAMBUJA',),
#  ('TORRES VEDRAS',),
#  ('SALVATERRA DE MAGOS',),
#  ('AZAMBUJA',),
#  ('ALENQUER',),
#  ('TORRES VEDRAS',),
#  ('FRONTEIRA',),
#  ('TORRES VEDRAS',),
#  ('CARTAXO',),
#  ('ALENQUER',),
#  ('FRONTEIRA',),
#  ('ARRONCHES',),
#  ('ALMEIRIM',),
#  ('AVIS',),
#  ('MONFORTE',),
#  ('ALCOCHETE',),
#  ('OEIRAS',),
#  ('ARRAIOLOS',),
#  ('OEIRAS',),
#  ('CASCAIS',),
#  ('CASCAIS',),
#  ('CASCAIS',),
#  ('CASCAIS',),
#  ('CASCAIS',),
#  ('MONTEMOR-O-NOVO',),
#  ('VILA VIÇOSA',),
#  ('CASCAIS',),
#  ('AZAMBUJA',),
#  ('LISBOA',),
#  ('LISBOA',),
#  ('CASCAIS',),
#  ('CASCAIS',),
#  ('LISBOA',),
#  ('CASCAIS',),
#  ('CASCAIS',),
#  ('CASCAIS',),
#  ('VENDAS NOVAS',),
#  ('AMADORA',),
#  ('REDONDO',),
#  ('SINTRA',),
#  ('AMADORA',),
#  ('LISBOA',),
#  ('ALMEIRIM',),
#  ('TORRES VEDRAS',),
#  ('CARTAXO',),
#  ('ALENQUER',),
#  ('CARTAXO',),
#  ('CARTAXO',),
#  ('ALENQUER',),
#  ('LISBOA',),
#  ('LOURES',),
#  ('ALENQUER',),
#  ('MONFORTE',),
#  ('TORRES VEDRAS',),
#  ('TORRES VEDRAS',),
#  ('CARTAXO',),
#  ('ARRONCHES',),
#  ('ALMEIRIM',),
#  ('CADAVAL',),
#  ('ARRONCHES',),
#  ('PONTE DE SOR',),
#  ('CARTAXO',),
#  ('SANTARÉM',),
#  ('LOURINHÃ',),
#  ('PONTE DE SOR',),
#  ('PONTE DE SOR',),
#  ('AVIS',),
#  ('SINTRA',),
#  ('ESTREMOZ',),
#  ('TORRES VEDRAS',),
#  ('LOURINHÃ',),
#  ('LOURINHÃ',),
#  ('ALTER DO CHÃO',),
#  ('LISBOA',),
#  ('LISBOA',),
#  ('AMADORA',),
#  ('SINTRA',),
#  ('ODIVELAS',),
#  ('ALMEIRIM',),
#  ('AZAMBUJA',),
#  ('LOURINHÃ',),
#  ('AZAMBUJA',),
#  ('CADAVAL',),
#  ('CADAVAL',),
#  ('ALTER DO CHÃO',),
#  ('LOURINHÃ',),
#  ('SANTARÉM',),
#  ('RIO MAIOR',),
#  ('PORTALEGRE',),
#  ('RIO MAIOR',),
#  ('CADAVAL',),
#  ('SANTARÉM',),
#  ('LOURES',),
#  ('BORBA',),
#  ('ODIVELAS',),
#  ('ODIVELAS',),
#  ('VILA VIÇOSA',),
#  ('ALTER DO CHÃO',),
#  ('BOMBARRAL',),
#  ('PORTALEGRE',),
#  ('LOURINHÃ',),
#  ('CADAVAL',),
#  ('CADAVAL',),
#  ('SANTARÉM',),
#  ('SINTRA',),
#  ('BORBA',),
#  ('SINTRA',),
#  ('ARRAIOLOS',),
#  ('ALCOCHETE',),
#  ('MONTEMOR-O-NOVO',),
#  ('ESTREMOZ',),
#  ('SINTRA',),
#  ('ODIVELAS',),
#  ('LOURES',),
#  ('LOURES',),
#  ('SINTRA',),
#  ('ARRAIOLOS',),
#  ('MONTIJO',),
#  ('VILA FRANCA DE XIRA',),
#  ('CORUCHE',),
#  ('ESTREMOZ',),
#  ('LOURES',),
#  ('ESTREMOZ',),
#  ('SINTRA',),
#  ('ELVAS',),
#  ('VILA FRANCA DE XIRA',),
#  ('MORA',),
#  ('LOURES',),
#  ('CORUCHE',),
#  ('LOURES',),
#  ('BENAVENTE',),
#  ('ARRAIOLOS',),
#  ('BORBA',),
#  ('ELVAS',),
#  ('SINTRA',),
#  ('ESTREMOZ',),
#  ('VILA FRANCA DE XIRA',),
#  ('LOURES',),
#  ('ESTREMOZ',),
#  ('MAFRA',),
#  ('MAFRA',),
#  ('BENAVENTE',),
#  ('VILA FRANCA DE XIRA',),
#  ('ARRUDA DOS VINHOS',),
#  ('ARRUDA DOS VINHOS',),
#  ('MAFRA',),
#  ('ELVAS',),
#  ('SOBRAL DE MONTE AGRAÇO',),
#  ('ELVAS',),
#  ('ARRUDA DOS VINHOS',),
#  ('ESTREMOZ',),
#  ('MAFRA',),
#  ('SOUSEL',),
#  ('SOUSEL',),
#  ('MORA',),
#  ('SANTARÉM',),
#  ('SANTA MARIA DA FEIRA',),
#  ('AROUCA',),
#  ('SERNANCELHE',),
#  ('SANTA MARIA DA FEIRA',),
#  ('SANTA MARIA DA FEIRA',),
#  ('SANTA MARIA DA FEIRA',),
#  ('MOIMENTA DA BEIRA',),
#  ('CASTRO DAIRE',),
#  ('FIGUEIRA DE CASTELO RODRIGO',),
#  ('CELORICO DA BEIRA',),
#  ('CASTRO DAIRE',),
#  ('AROUCA',),
#  ('MOIMENTA DA BEIRA',),
#  ('VILA VERDE',),
#  ('PENEDONO',),
#  ('AROUCA',),
#  ('CASTRO DAIRE',),
#  ('SANTA MARIA DA FEIRA',),
#  ('PINHEL',),
#  ('OVAR',),
#  ('CASTRO DAIRE',),
#  ('CASTRO DAIRE',),
#  ('SANTA MARIA DA FEIRA',),
#  ('CASTRO DAIRE',),
#  ('MÊDA',),
#  ('IDANHA-A-NOVA',),
#  ('OLEIROS',),
#  ('SOURE',),
#  ('OLEIROS',),
#  ('CASTELO BRANCO',),
#  ('IDANHA-A-NOVA',),
#  ('PENEDONO',),
#  ('CASTELO BRANCO',),
#  ('ANSIÃO',),
#  ('PAMPILHOSA DA SERRA',),
#  ('OLEIROS',),
#  ('MOIMENTA DA BEIRA',),
#  ('AROUCA',),
#  ('OLEIROS',),
#  ('PEDRÓGÃO GRANDE',),
#  ('PENELA',),
#  ('POMBAL',),
#  ('POMBAL',),
#  ('SOURE',),
#  ('AVEIRO',),
#  ('SERNANCELHE',),
#  ('ESPINHO',),
#  ('SANTA MARIA DA FEIRA',),
#  ('CASTRO DAIRE',),
#  ('FIGUEIRA DE CASTELO RODRIGO',),
#  ('SANTA MARIA DA FEIRA',),
#  ('MOIMENTA DA BEIRA',),
#  ('AROUCA',),
#  ('CASTRO DAIRE',),
#  ('RESENDE',),
#  ('CINFÃES',),
#  ('TABUAÇO',),
#  ('TAROUCA',),
#  ('VILA NOVA DE GAIA',),
#  ('PENEDONO',),
#  ('GONDOMAR',),
#  ('VILA NOVA DE GAIA',),
#  ('ALPIARÇA',),
#  ('CASTELO BRANCO',),
#  ('PEDRÓGÃO GRANDE',),
#  ('CASTELO BRANCO',),
#  ('LEIRIA',),
#  ('OLEIROS',),
#  ('ANSIÃO',),
#  ('IDANHA-A-NOVA',),
#  ('POMBAL',),
#  ('CASTELO BRANCO',),
#  ('ANSIÃO',),
#  ('POMBAL',),
#  ('OLEIROS',),
#  ...]
