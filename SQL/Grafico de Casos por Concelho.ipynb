# %%
# %load_ext sql

# %%
# %sql postgresql://postgres:1234@localhost/covid
# Out:
# 'Connected: postgres@covid'

# %%
concelhos_sem_casos= %sql select count (*) from confirmados_concelho where mais_recente is NULL
# Out:
#    postgresql://postgres:***@localhost/MIEBIOM
#  * postgresql://postgres:***@localhost/covid
# 1 rows affected.

# %%
concelhos_sem_casos
# Out:
# [(87,)]

# %%
result = %sql SELECT concelho, mais_recente FROM confirmados_concelho WHERE mais_recente >500
# usando diretamente o resultado, em que type(result) = sql.run.ResultSet
# %matplotlib notebook
result.pie()
# Out:
#    postgresql://postgres:***@localhost/MIEBIOM
#  * postgresql://postgres:***@localhost/covid
# 11 rows affected.
# <img src="data:image/png;base64,..." width="640">
# ([<matplotlib.patches.Wedge at 0x20fda569e80>,
#   <matplotlib.patches.Wedge at 0x20fda933400>,
#   <matplotlib.patches.Wedge at 0x20fda9338d0>,
#   <matplotlib.patches.Wedge at 0x20fda933dd8>,
#   <matplotlib.patches.Wedge at 0x20fda93b2e8>,
#   <matplotlib.patches.Wedge at 0x20fda93b7b8>,
#   <matplotlib.patches.Wedge at 0x20fda93bc88>,
#   <matplotlib.patches.Wedge at 0x20fda943198>,
#   <matplotlib.patches.Wedge at 0x20fda943668>,
#   <matplotlib.patches.Wedge at 0x20fda943b38>,
#   <matplotlib.patches.Wedge at 0x20fda54cb38>],
#  [Text(1.082720107996153, 0.19420908253940852, 'SINTRA'),
#   Text(0.8172139286848101, 0.7363160970422542, 'PORTO'),
#   Text(0.1548450189257036, 1.0890468401836069, 'MATOSINHOS'),
#   Text(-0.5947049149539251, 0.9253788759906101, 'VILA NOVA DE GAIA'),
#   Text(-1.0004523721572962, 0.45726912321393326, 'OVAR'),
#   Text(-1.0986596723397875, -0.05428558164219078, 'GONDOMAR'),
#   Text(-0.8624583280991788, -0.6827632329676002, 'BRAGA'),
#   Text(-0.3508834438960913, -1.0425357590028357, 'MAIA'),
#   Text(0.10091135727885137, -1.095361537562891, 'GUIMARÃES'),
#   Text(0.7017277059915369, -0.8470998917741963, 'LISBOA'),
#   Text(1.0737911144949104, -0.23868942672807777, 'VALONGO')])
